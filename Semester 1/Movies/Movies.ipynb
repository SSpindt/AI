# %%
import pandas as pd
import seaborn as sns
import requests
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Now Playing Endpoint
url = "https://api.themoviedb.org/3/movie/now_playing?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
}

response = requests.get(url, headers=headers)
response = response.json()
now = pd.DataFrame(response["results"])
now.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 2  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
# 3  False  /3m0j3hCS8kMAaP9El6Vy5Lqnyft.jpg     [878, 53, 18]  1125510
# 4  False  /xi1VSt3DtkevUmzCx2mNlCoDe74.jpg      [35, 14, 27]   917496
#
#   original_language           original_title  \
# 0                en           The Wild Robot
# 1                en            The Substance
# 2                en                   Azrael
# 3                es                El hoyo 2
# 4                en  Beetlejuice Beetlejuice
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    7456.608
# 1  A fading celebrity decides to use a black mark...    4852.638
# 2  In a world where no one speaks, a devout femal...    2309.545
# 3  After a mysterious leader imposes his law in a...    1781.297
# 4  After a family tragedy, three generations of t...    2059.319
#
#                         poster_path release_date                    title  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12           The Wild Robot
# 1  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07            The Substance
# 2  /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27                   Azrael
# 3  /izuzUb0sDokqp9o8utVfsrSJuy5.jpg   2024-09-27           The Platform 2
# 4  /kKgQzkUCnQmeTPkyIwHly2t6ZFI.jpg   2024-09-04  Beetlejuice Beetlejuice
#
#    video  vote_average  vote_count
# 0  False         8.700        1060
# 1  False         7.300         718
# 2  False         6.000          78
# 3  False         5.700         645
# 4  False         7.203        1445

# %%
# Popular

url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
}

response = requests.get(url, headers=headers)
response = response.json()
pop = pd.DataFrame(response["results"])

# %%
# Top Rated

url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
}

response = requests.get(url, headers=headers)
response = response.json()
top = pd.DataFrame(response["results"])

# %%
# Upcoming
url = "https://api.themoviedb.org/3/movie/upcoming?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
}

response = requests.get(url, headers=headers)
response = response.json()
up = pd.DataFrame(response["results"])

# %%
df = pd.concat([now, pop, top, up])

# %%
df.drop_duplicates(subset=['id'], inplace=True)

# %%
def get_revenue_budget(df):
    '''
    Uses the movie id to get data from the "Details" endpoint
    Returns a dataframe of revenue and budget data
    '''
    data = {
        "id":[],
        "budget": [],
        "revenue": []
    }

    for i in df["id"]:
        data["id"].append(i)
        url = "https://api.themoviedb.org/3/movie/"+str(i)+"?language=en-US"

        headers = {
            "accept": "application/json",
            "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
        }

        response = requests.get(url, headers=headers)
        response = response.json()
        data["budget"].append(response["budget"])
        data["revenue"].append(response["revenue"])
        
    return pd.DataFrame(data)

# %%
money_df = get_revenue_budget(df)

# %%
money_df.head()
# Out:
#         id     budget    revenue
# 0  1184918   78000000  196822000
# 1   933260   17500000   29106531
# 2  1029235   12000000          0
# 3  1125510          0          0
# 4   917496  100000000  434090643

# %%
df = pd.merge(df, money_df, how="inner", on="id")

# %%
df.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 2  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
# 3  False  /3m0j3hCS8kMAaP9El6Vy5Lqnyft.jpg     [878, 53, 18]  1125510
# 4  False  /xi1VSt3DtkevUmzCx2mNlCoDe74.jpg      [35, 14, 27]   917496
#
#   original_language           original_title  \
# 0                en           The Wild Robot
# 1                en            The Substance
# 2                en                   Azrael
# 3                es                El hoyo 2
# 4                en  Beetlejuice Beetlejuice
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    7456.608
# 1  A fading celebrity decides to use a black mark...    4852.638
# 2  In a world where no one speaks, a devout femal...    2309.545
# 3  After a mysterious leader imposes his law in a...    1781.297
# 4  After a family tragedy, three generations of t...    2059.319
#
#                         poster_path release_date                    title  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12           The Wild Robot
# 1  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07            The Substance
# 2  /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27                   Azrael
# 3  /izuzUb0sDokqp9o8utVfsrSJuy5.jpg   2024-09-27           The Platform 2
# 4  /kKgQzkUCnQmeTPkyIwHly2t6ZFI.jpg   2024-09-04  Beetlejuice Beetlejuice
#
#    video  vote_average  vote_count     budget    revenue
# 0  False         8.700        1060   78000000  196822000
# 1  False         7.300         718   17500000   29106531
# 2  False         6.000          78   12000000          0
# 3  False         5.700         645          0          0
# 4  False         7.203        1445  100000000  434090643

# %%
sns.regplot(data=df, x="budget", y="revenue")
# Out:
# <AxesSubplot:xlabel='budget', ylabel='revenue'>

# %%
import numpy as np
df["revenue_sqrt"] = np.sqrt(df["revenue"])
df["budget_sqrt"] = np.sqrt(df["budget"])

# %%
df.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 2  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
# 3  False  /3m0j3hCS8kMAaP9El6Vy5Lqnyft.jpg     [878, 53, 18]  1125510
# 4  False  /xi1VSt3DtkevUmzCx2mNlCoDe74.jpg      [35, 14, 27]   917496
#
#   original_language           original_title  \
# 0                en           The Wild Robot
# 1                en            The Substance
# 2                en                   Azrael
# 3                es                El hoyo 2
# 4                en  Beetlejuice Beetlejuice
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    7456.608
# 1  A fading celebrity decides to use a black mark...    4852.638
# 2  In a world where no one speaks, a devout femal...    2309.545
# 3  After a mysterious leader imposes his law in a...    1781.297
# 4  After a family tragedy, three generations of t...    2059.319
#
#                         poster_path release_date                    title  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12           The Wild Robot
# 1  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07            The Substance
# 2  /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27                   Azrael
# 3  /izuzUb0sDokqp9o8utVfsrSJuy5.jpg   2024-09-27           The Platform 2
# 4  /kKgQzkUCnQmeTPkyIwHly2t6ZFI.jpg   2024-09-04  Beetlejuice Beetlejuice
#
#    video  vote_average  vote_count     budget    revenue  revenue_sqrt  \
# 0  False         8.700        1060   78000000  196822000  14029.326427
# 1  False         7.300         718   17500000   29106531   5395.046895
# 2  False         6.000          78   12000000          0      0.000000
# 3  False         5.700         645          0          0      0.000000
# 4  False         7.203        1445  100000000  434090643  20834.842044
#
#     budget_sqrt
# 0   8831.760866
# 1   4183.300133
# 2   3464.101615
# 3      0.000000
# 4  10000.000000

# %%
def get_best_fit(data, x, y):
    '''
    Determines the slope (m) and intercept (b) of the best fit line
    for two variables, x and y.
    '''
    m = 0
    for count in range(100):
        m = m + 1
        b = 0

        # Calculate residuals (y = mx+b)
        res = 0
        for i in range(len(data)):
            pred_y = (m * data.loc[i][x]) + b
            act_y = data.loc[i][y]
            temp = act_y - pred_y 
            temp = temp ** 2
            res = res + temp
        print(res)
    return (m, b, res)

# %%
get_best_fit(df, "budget_sqrt", "revenue_sqrt")
# Out:
# 4800737914.215089
# 2768805710.430177
# 4641465008.645264
# 10418715808.860352
# 20100558111.07544
# 33686991915.290524
# 51178017221.50563
# 72573634029.72072
# 97873842339.93579
# 127078642152.15085
# 160188033466.36588
# 197202016282.5811
# 238120590600.7961
# 282943756421.01117
# 331671513743.2263
# 384303862567.44147
# 440840802893.65643
# 501282334721.8715
# 565628458052.0867
# 633879172884.3015
# 706034479218.517
# 782094377054.7318
# 862058866392.9474
# 945927947233.162
# 1033701619575.3772
# 1125379883419.5925
# 1220962738765.8076
# 1320450185614.0222
# 1423842223964.2375
# 1531138853816.4526
# 1642340075170.6672
# 1757445888026.8828
# 1876456292385.098
# 1999371288245.3132
# 2126190875607.528
# 2256915054471.7437
# 2391543824837.9585
# 2530077186706.1724
# 2672515140076.3887
# 2818857684948.604
# 2969104821322.819
# 3123256549199.0337
# 3281312868577.2485
# 3443273779457.4644
# 3609139281839.678
# 3778909375723.893
# 3952584061110.109
# 4130163337998.3237
# 4311647206388.5405
# 4497035666280.755
# 4686328717674.969
# 4879526360571.186
# 5076628594969.401
# 5277635420869.615
# 5482546838271.83
# 5691362847176.047
# 5904083447582.261
# 6120708639490.473
# 6341238422900.691
# 6565672797812.904
# 6794011764227.121
# 7026255322143.334
# 7262403471561.551
# 7502456212481.766
# 7746413544903.981
# 7994275468828.196
# 8246041984254.411
# 8501713091182.627
# 8761288789612.838
# 9024769079545.057
# 9292153960979.271
# 9563443433915.484
# 9838637498353.7
# 10117736154293.914
# 10400739401736.135
# 10687647240680.35
# 10978459671126.562
# 11273176693074.775
# 11571798306524.994
# 11874324511477.203
# 12180755307931.422
# 12491090695887.633
# 12805330675345.854
# 13123475246306.064
# 13445524408768.283
# 13771478162732.5
# 14101336508198.713
# 14435099445166.926
# 14772766973637.146
# 15114339093609.357
# 15459815805083.574
# 15809197108059.787
# 16162483002538.0
# 16519673488518.215
# 16880768566000.432
# 17245768234984.648
# 17614672495470.863
# 17987481347459.074
# 18364194790949.297
# 18744812825941.51
# (100, 0, 18744812825941.51)

# %%
# Luis: y = 1.78x + 1279 
# Caleb: y = 0.724x + 0.783
# Zach: y = 1.896x + 1028.934

# Luis
rev1 = 100 * 5000000

# Caleb
rev2 = 0.724*5000000 + 0.783

# Zach
rev3 = 1.896*5000000 + 1028.934

# %%
df.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 2  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
# 3  False  /3m0j3hCS8kMAaP9El6Vy5Lqnyft.jpg     [878, 53, 18]  1125510
# 4  False  /xi1VSt3DtkevUmzCx2mNlCoDe74.jpg      [35, 14, 27]   917496
#
#   original_language           original_title  \
# 0                en           The Wild Robot
# 1                en            The Substance
# 2                en                   Azrael
# 3                es                El hoyo 2
# 4                en  Beetlejuice Beetlejuice
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    7456.608
# 1  A fading celebrity decides to use a black mark...    4852.638
# 2  In a world where no one speaks, a devout femal...    2309.545
# 3  After a mysterious leader imposes his law in a...    1781.297
# 4  After a family tragedy, three generations of t...    2059.319
#
#                         poster_path release_date                    title  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12           The Wild Robot
# 1  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07            The Substance
# 2  /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27                   Azrael
# 3  /izuzUb0sDokqp9o8utVfsrSJuy5.jpg   2024-09-27           The Platform 2
# 4  /kKgQzkUCnQmeTPkyIwHly2t6ZFI.jpg   2024-09-04  Beetlejuice Beetlejuice
#
#    video  vote_average  vote_count     budget    revenue  revenue_sqrt  \
# 0  False         8.700        1060   78000000  196822000  14029.326427
# 1  False         7.300         718   17500000   29106531   5395.046895
# 2  False         6.000          78   12000000          0      0.000000
# 3  False         5.700         645          0          0      0.000000
# 4  False         7.203        1445  100000000  434090643  20834.842044
#
#     budget_sqrt
# 0   8831.760866
# 1   4183.300133
# 2   3464.101615
# 3      0.000000
# 4  10000.000000

# %%
print(rev1, rev2, rev3)
# Out:
# 500000000 3620000.783 9481028.934

# %%
# Step 1: Calculate the Sum of Squares Total; this is (y - mean of y)
# Step 2: Calculate the Sum of Squares Residuals; this is (y predicted - y actual)
# Step 3: R2 = 1 - (SSR / SST)

def get_r2(df, x, y, m, b):
    mean = df[y].mean()
    total_sst = 0
    # Calculate SST
    for value in df[y]:
        difference = (value - mean)
        squared = difference ** 2
        total_sst += squared
    
    total_ssr = 0
    # Calculate SSR
    for i in range(len(df)):
        predicted = (m * df.loc[i][x]) + b
        difference = predicted - df.loc[i][y]
        squared = difference ** 2
        total_ssr += squared
    
    r2 = 1 - (total_ssr / total_sst)
    return r2

# %%
get_r2(df, "budget", "revenue", 1.896, 1028.934)
# Out:
# 0.24169769290630683

# %%
# Luis - r2 0.21
# Caleb - check
# Zach - r2 0.24


# The r2 value should be close to 1 for a linear model to be seen as accurate!

# %%
# Popular 
action = []
romance = []
url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
}
response = requests.get(url, headers=headers)
response = response.json()["results"]
for i in range(len(response)):
    genres = response[i]["genre_ids"]
    if 28 in genres and 10749 in genres:
        action.append(response[i])
        romance.append(response[i])
    elif 28 in genres:
        action.append(response[i])
    elif 10749 in genres:
        romance.append(response[i])
action = pd.DataFrame(action)
romance = pd.DataFrame(romance)

# %%
action.head()
# Out:
#    adult                     backdrop_path            genre_ids       id  \
# 0  False  /yDHYTfA3R0jFYba16jBB1ef8oIt.jpg        [28, 35, 878]   533535
# 1  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg         [28, 27, 53]  1029235
# 2  False  /3V4kLQg0kSqPLctI5ziYWabAZYF.jpg        [28, 878, 12]   912649
# 3  False  /lgkPzcOSnTvjeMnuFzozRO5HHw1.jpg  [16, 10751, 35, 28]   519182
# 4  False  /g1z1ZvYKcmk9EnVOTYXR6vkNjkZ.jpg         [14, 27, 28]  1087822
#
#   original_language            original_title  \
# 0                en      Deadpool & Wolverine
# 1                en                    Azrael
# 2                en     Venom: The Last Dance
# 3                en           Despicable Me 4
# 4                en  Hellboy: The Crooked Man
#
#                                             overview  popularity  \
# 0  A listless Wade Wilson toils away in civilian ...    2203.301
# 1  In a world where no one speaks, a devout femal...    1635.458
# 2  Eddie and Venom are on the run. Hunted by both...    1678.855
# 3  Gru and Lucy and their girls—Margo, Edith and ...    1195.583
# 4  Hellboy and a rookie BPRD agent get stranded i...    1221.335
#
#                         poster_path release_date                     title  \
# 0  /8cdWjvZQUExUUTzyp4t6EDMubfO.jpg   2024-07-24      Deadpool & Wolverine
# 1  /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27                    Azrael
# 2  /k42Owka8v91trK1qMYwCQCNwJKr.jpg   2024-10-22     Venom: The Last Dance
# 3  /3w84hCFJATpiCO5g8hpdWVPBbmq.jpg   2024-06-20           Despicable Me 4
# 4  /iz2GabtToVB05gLTVSH7ZvFtsMM.jpg   2024-08-29  Hellboy: The Crooked Man
#
#    video  vote_average  vote_count
# 0  False         7.712        4723
# 1  False         6.095          84
# 2  False         7.175          20
# 3  False         7.100        2036
# 4  False         5.000         145

# %%
action = action.drop_duplicates(subset=['id'])
action
# Out:
#     adult                     backdrop_path genre_ids       id  \
# 0   False  /wPNI1fd18z5TKBOK9Mv9Rfjb0j0.jpg        53   729165
# 4   False  /vwwHt1hNvPpAUEFW6YHdhy9jJmY.jpg        28  1085046
# 9   False  /kdbLf3aTQsEXqYlH9vA4fzmnSFz.jpg     10752   228150
# 12  False  /vblTCXOWUQGSc837vgbhDRi4HSc.jpg        28   955555
# 16  False  /aA5B2OsN6rccwnhn8TEG4m4V3jI.jpg        80  1059064
# 19  False  /stCsaDfmQRUILjBlx9jeUtiTwl3.jpg        28   634492
# 21  False  /oBIQDKcqNxKckjugtmzpIIOgoc4.jpg        28   969492
# 24  False  /xFYpUmB01nswPgbzi8EOCT1ZYFu.jpg        12   980489
# 27  False  /AaV1YIdWKnjAIAOe8UUKBFm327v.jpg        28   361743
# 29  False  /uzIGtyS6bbnJzGsPL93WCF1FWm8.jpg        12     1865
# 32  False  /wkPPRIducGfsbaUPsWfw0MCQdX7.jpg        28  1051891
# 35  False  /ahYDVW0ReOTKI6sbI6du9SoXdX9.jpg        28   666035
# 36  False  /fY3lD0jM5AoHJMunjGWqJ0hRteI.jpg       878   940721
# 39  False  /oe7mWkvYhK4PLRNAVSvonzyUXNy.jpg        28   359410
# 41  False  /9iQWsXwjOMGDvTDdvCnpiyR0UG3.jpg        28     8681
# 43  False  /3TNSoa0UHGEzEz5ndXGjJVKo8RJ.jpg       878   614933
# 45  False  /cnqwv5Uz3UW5f086IWbQKr3ksJr.jpg        28   572802
# 48  False  /yF1eOkaYvwiORauRCPWznV9xVvi.jpg        12   298618
# 51  False  /brnfCYyz8EMbBrHgmh8sCwBi5i1.jpg        27   396535
# 55  False  /k0hlAzTryCYX1O1LyC6P8tAa8s0.jpg        28   102382
# 58  False  /xYyPLClpJiA5pq687pGjRel5qgf.jpg        28  1064375
# 60  False  /rAksPS6LjBONzY84szQBz5gGej6.jpg        28   566525
# 63  False  /5mzr6JZbrqnqD8rCEvPhuCE5Fw2.jpg        28   615656
# 66  False  /9Y9wTgrMk4G1YNPDDekNk7dybwx.jpg        28  1152624
# 69  False  /698FjyzLdpgXmUSr63LaRwblTmx.jpg        12   507086
# 72  False  /5YZbUmjbMa3ClvSW1Wj3D6XGolb.jpg       878   447365
# 75  False   /QflfyU07MiQXSqTUCmG9Xfq0Ws.jpg        28  1281826
# 78  False  /hND7xAaxxBgaIspp9iMsaEXOSTz.jpg        28       98
# 81  False  /uFvYlyWN24gxkDIaWEmMuQMYbqB.jpg        53  1028703
# 84  False   /H5HjE7Xb9N09rbWn1zBfxgI8uz.jpg        28   746036
# 86  False  /rrwt0u1rW685u9bJ9ougg5HJEHC.jpg        28   280180
# 89  False    /jfEOzpsjc6JDlKhUHb4toWQPt.jpg        12      121
# 92  False  /4s2d3xdyqotiVNHTlTlJjrr3q0H.jpg        12   177572
# 97  False  /aswBReNN2adqTiOBnvh96RCDeJP.jpg        28   959092
#
#    original_language                               original_title  \
# 0                 en                                 Out of Exile
# 4                 zh                                  超级英雄美猴王：齐天儿
# 9                 en                                         Fury
# 12                ko                                       범죄도시 3
# 16                en                              The Instigators
# 19                en                                   Madame Web
# 21                en                                  Land of Bad
# 24                en                                 Gran Turismo
# 27                en                            Top Gun: Maverick
# 29                en  Pirates of the Caribbean: On Stranger Tides
# 32                en                                       Thelma
# 35                en                                   Wanted Man
# 36                ja                                      ゴジラ-1.0
# 39                en                                   Road House
# 41                en                                        Taken
# 43                en                                        Atlas
# 45                en                 Aquaman and the Lost Kingdom
# 48                en                                    The Flash
# 51                ko                                          부산행
# 55                en                     The Amazing Spider-Man 2
# 58                en                               Paradox Effect
# 60                en    Shang-Chi and the Legend of the Ten Rings
# 63                en                            Meg 2: The Trench
# 66                en                              3 Days in Malay
# 69                en                      Jurassic World Dominion
# 72                en               Guardians of the Galaxy Vol. 3
# 75                en                                One Fast Move
# 78                en                                    Gladiator
# 81                en                                The OctoGames
# 84                en                                 The Fall Guy
# 86                en                    Beverly Hills Cop: Axel F
# 89                en        The Lord of the Rings: The Two Towers
# 92                en                                   Big Hero 6
# 97                fr                                       Farang
#
#                                              overview  popularity  \
# 0   Recently paroled thief Gabriel Russell tries t...      98.173
# 4   Shimmy, a monkey newly discover superhero powe...     161.538
# 9   In the last months of World War II, as the All...     107.137
# 12  Detective Ma Seok-do changes his affiliation f...     120.781
# 16  Rory and Cobby are unlikely partners thrown to...     108.254
# 19  Forced to confront revelations about her past,...     108.099
# 21  When a Delta Force special ops mission goes te...     109.148
# 24  The ultimate wish-fulfillment tale of a teenag...      96.504
# 27  After more than thirty years of service as one...     134.579
# 29  Captain Jack Sparrow crosses paths with a woma...     119.842
# 32  When 93-year-old Thelma Post gets duped by a p...     103.047
# 35  Follows a police officer who must retrieve an ...     100.259
# 36  In postwar Japan, Godzilla brings new devastat...     112.363
# 39  Ex-UFC fighter Dalton takes a job as a bouncer...     145.942
# 41  While vacationing with a friend in Paris, an A...     115.113
# 43  A brilliant counterterrorism analyst with a de...      99.833
# 45  Black Manta seeks revenge on Aquaman for his f...     103.430
# 48  When his attempt to save his family inadverten...     102.676
# 51  When a zombie virus pushes Korea into a state ...     111.672
# 55  For Peter Parker, life is busy. Between taking...     172.694
# 58  An innocent woman is forced to confront a dang...     176.425
# 60  Shang-Chi must confront the past he thought he...     121.095
# 63  An exploratory dive into the deepest depths of...      94.478
# 66  Marines stationed at an airfield in Malay duri...     100.086
# 69  Four years after Isla Nublar was destroyed, di...     125.757
# 72  Peter Quill, still reeling from the loss of Ga...     115.544
# 75  A dishonorably discharged soldier seeks out hi...     113.947
# 78  In the year 180, the death of emperor Marcus A...     121.494
# 81  Eight contestants compete in eight deadly, cla...     184.143
# 84  Fresh off an almost career-ending accident, st...     135.547
# 86  Forty years after his unforgettable first case...     116.879
# 89  Frodo Baggins and the other members of the Fel...     114.068
# 92  A special bond develops between plus-sized inf...     121.228
# 97  Sam is a professional boxer about to get relea...     130.983
#
#                          poster_path release_date  \
# 0   /jgF5XaXnJmOgMxulhy2k1f9LNNc.jpg   2023-01-20
# 4   /ktvSdBzYts4voUO0FJG5O6FOcPI.jpg   2023-04-21
# 9   /pfte7wdMobMF4CVHuOxyu6oqeeA.jpg   2014-10-15
# 12  /lW6IHrtaATxDKYVYoQGU5sh0OVm.jpg   2023-05-31
# 16  /pIz9csYn1yjrzQi0BuBZNJrTMi0.jpg   2024-08-02
# 19  /rULWuutDcN5NvtiZi4FRPzRYWSh.jpg   2024-02-14
# 21  /h3jYanWMEJq6JJsCopy1h7cT2Hs.jpg   2024-02-09
# 24  /51tqzRtKMMZEYUpSYkrUE7v9ehm.jpg   2023-08-09
# 27  /62HCnUTziyWcpDaBO2i1DX17ljH.jpg   2022-05-21
# 29  /keGfSvCmYj7CvdRx36OdVrAEibE.jpg   2011-05-15
# 32  /rUcuageYgv9SsJoWuc0seRWG6JC.jpg   2024-06-21
# 35  /pmdgdb8biQLLzTjySZLPdK13KwM.jpg   2024-04-01
# 36  /hkxxMIGaiCTmrEArK7J56JTKUlB.jpg   2023-11-03
# 39  /lwPsIgh98Wnpvkr3svkZwlhDrfm.jpg   2024-03-08
# 41  /y5Va1WXDX6nZElVirPrGxf6w99B.jpg   2008-02-18
# 43  /bcM2Tl5HlsvPBnL8DKP9Ie6vU4r.jpg   2024-05-23
# 45  /7lTnXOy0iNtBAdRP3TZvaKJ77F6.jpg   2023-12-20
# 48  /rktDFPbfHfUbArZ6OOOKsXcv0Bm.jpg   2023-06-13
# 51  /vNVFt6dtcqnI7hqa6LFBUibuFiw.jpg   2016-07-20
# 55  /kV61FAIsRWZP6JhgWFOKug9RbBx.jpg   2014-04-16
# 58  /koJFEW997sLjpu4e7wmFioA2mhL.jpg   2024-06-27
# 60  /9f2Q0U3IOsLgrI2HkvldwSABZy5.jpg   2021-09-01
# 63  /4m1Au3YkjqsxF8iwQy0fPYSxE0h.jpg   2023-08-02
# 66  /hqnfqeCILvgKGWKOut5lVdxdeJh.jpg   2023-08-11
# 69  /i74yGY5QMgq6seceDhltaPJ0xfO.jpg   2022-06-01
# 72  /r2J02Z2OpNTctfOSN1Ydgii51I3.jpg   2023-05-03
# 75  /hdBUjfbdr1ymS0kycAT7qguOmWA.jpg   2024-08-07
# 78  /ty8TGRuvJLPUmAR1H1nRIsgwvim.jpg   2000-05-04
# 81  /qGz5rffXhegQH5PGUDiObqoOt06.jpg   2022-10-07
# 84  /tSz1qsmSJon0rqjHBxXZmrotuse.jpg   2024-04-24
# 86  /zszRKfzjM5jltiq8rk6rasKVpUv.jpg   2024-06-20
# 89  /5VTN0pR8gcqV3EPUHHfMGnJYN9L.jpg   2002-12-18
# 92  /2mxS4wUimwlLmI1xp6QW6NSU361.jpg   2014-10-24
# 97  /u9035lysUz3ccloQt0SeIp1Mu8a.jpg   2023-06-28
#
#                                           title  video  vote_average  \
# 0                                  Out of Exile  False         6.400
# 4                 Shimmy: The First Monkey King  False         5.800
# 9                                          Fury  False         7.500
# 12                      The Roundup: No Way Out  False         7.202
# 16                              The Instigators  False         6.200
# 19                                   Madame Web  False         5.500
# 21                                  Land of Bad  False         7.300
# 24                                 Gran Turismo  False         7.800
# 27                            Top Gun: Maverick  False         8.203
# 29  Pirates of the Caribbean: On Stranger Tides  False         6.600
# 32                                       Thelma  False         7.072
# 35                                   Wanted Man  False         6.900
# 36                           Godzilla Minus One  False         7.600
# 39                                   Road House  False         7.000
# 41                                        Taken  False         7.392
# 43                                        Atlas  False         6.816
# 45                 Aquaman and the Lost Kingdom  False         6.675
# 48                                    The Flash  False         6.700
# 51                               Train to Busan  False         7.755
# 55                     The Amazing Spider-Man 2  False         6.511
# 58                               Paradox Effect  False         5.775
# 60    Shang-Chi and the Legend of the Ten Rings  False         7.548
# 63                            Meg 2: The Trench  False         6.490
# 66                              3 Days in Malay  False         5.200
# 69                      Jurassic World Dominion  False         6.700
# 72               Guardians of the Galaxy Vol. 3  False         8.000
# 75                                One Fast Move  False         6.700
# 78                                    Gladiator  False         8.217
# 81                                The OctoGames  False         5.400
# 84                                 The Fall Guy  False         7.200
# 86                    Beverly Hills Cop: Axel F  False         6.800
# 89        The Lord of the Rings: The Two Towers  False         8.400
# 92                                   Big Hero 6  False         7.700
# 97                                      Mayhem!  False         6.700
#
#     vote_count
# 0           39
# 4           32
# 9        11859
# 12         420
# 16         352
# 19        1883
# 21        1091
# 24        2629
# 27        9124
# 29       13884
# 32         125
# 35          74
# 36        2221
# 39        2227
# 41       11098
# 43        1188
# 45        2746
# 48        4193
# 51        7362
# 55       13131
# 58          40
# 60        9315
# 63        3356
# 66          27
# 69        6021
# 72        6759
# 75         148
# 78       18358
# 81         118
# 84        2159
# 86        1033
# 89       21732
# 92       15515
# 97         157

# %%
page = 2
while len(action) < 100 or len(romance) < 100:
    url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=" + str(page)

    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
    }
    response = requests.get(url, headers=headers)
    response = response.json()["results"]
    page += 1
    for i in range(len(response)):
        genres = response[i]["genre_ids"]
        temp = pd.DataFrame(response[i])
        if 28 in genres:
            action = pd.concat([temp, action], ignore_index=True)
        if 10749 in genres:
            romance = pd.concat([temp, romance], ignore_index=True)

# %%
print(len(action), len(romance))
action = action[:100]
romance = romance[:100]
# Out:
# 100 102

# %%
print(len(action), len(romance))
# Out:
# 100 100

# %%
action.head()
# Out:
#    adult                     backdrop_path genre_ids       id  \
# 0  False  /wPNI1fd18z5TKBOK9Mv9Rfjb0j0.jpg        53   729165
# 1  False  /wPNI1fd18z5TKBOK9Mv9Rfjb0j0.jpg        18   729165
# 2  False  /wPNI1fd18z5TKBOK9Mv9Rfjb0j0.jpg        28   729165
# 3  False  /wPNI1fd18z5TKBOK9Mv9Rfjb0j0.jpg        80   729165
# 4  False  /vwwHt1hNvPpAUEFW6YHdhy9jJmY.jpg        28  1085046
#
#   original_language original_title  \
# 0                en   Out of Exile
# 1                en   Out of Exile
# 2                en   Out of Exile
# 3                en   Out of Exile
# 4                zh    超级英雄美猴王：齐天儿
#
#                                             overview  popularity  \
# 0  Recently paroled thief Gabriel Russell tries t...      98.173
# 1  Recently paroled thief Gabriel Russell tries t...      98.173
# 2  Recently paroled thief Gabriel Russell tries t...      98.173
# 3  Recently paroled thief Gabriel Russell tries t...      98.173
# 4  Shimmy, a monkey newly discover superhero powe...     161.538
#
#                         poster_path release_date  \
# 0  /jgF5XaXnJmOgMxulhy2k1f9LNNc.jpg   2023-01-20
# 1  /jgF5XaXnJmOgMxulhy2k1f9LNNc.jpg   2023-01-20
# 2  /jgF5XaXnJmOgMxulhy2k1f9LNNc.jpg   2023-01-20
# 3  /jgF5XaXnJmOgMxulhy2k1f9LNNc.jpg   2023-01-20
# 4  /ktvSdBzYts4voUO0FJG5O6FOcPI.jpg   2023-04-21
#
#                            title  video  vote_average  vote_count
# 0                   Out of Exile  False           6.4          39
# 1                   Out of Exile  False           6.4          39
# 2                   Out of Exile  False           6.4          39
# 3                   Out of Exile  False           6.4          39
# 4  Shimmy: The First Monkey King  False           5.8          32
